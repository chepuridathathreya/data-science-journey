# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

X = np.array([
    [1, 1],
    [1.5, 2],
    [3, 4],
    [5, 7],
    [3.5, 5],
    [4.5, 5],
    [3.5, 4.5]
])

# %%
model = KMeans(n_clusters=2, random_state=42)
model.fit(X)
labels = model.labels_
print(labels)
# Out:
# [0 0 1 1 1 1 1]
# c:\Users\NATRAJ\miniconda3\envs\datascience\Lib\site-packages\sklearn\cluster\_kmeans.py:1428: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
plt.scatter(X[:, 0], X[:, 1], c=labels, s=100)

plt.scatter(
    model.cluster_centers_[:, 0],
    model.cluster_centers_[:, 1],
    marker="X",
    s=250
)

plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("K-Means Clustering")

plt.show()

# %% [markdown]
# Cluster 0 → [1,1], [1.5,2]
#
# Cluster 1 → [3,4], [5,7], [3.5,5],
#              [4.5,5], [3.5,4.5]

# %%
inertias = []

for k in range(1, 8):
    model = KMeans(
        n_clusters=k,
        random_state=42
    )

    model.fit(X)
    inertias.append(model.inertia_)
plt.plot(range(1, 8), inertias, marker="o")

plt.xlabel("Number of Clusters (K)")
plt.ylabel("Inertia")
plt.title("Elbow Method")

plt.show()
# Out:
# c:\Users\NATRAJ\miniconda3\envs\datascience\Lib\site-packages\sklearn\cluster\_kmeans.py:1428: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\NATRAJ\miniconda3\envs\datascience\Lib\site-packages\sklearn\cluster\_kmeans.py:1428: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\NATRAJ\miniconda3\envs\datascience\Lib\site-packages\sklearn\cluster\_kmeans.py:1428: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\NATRAJ\miniconda3\envs\datascience\Lib\site-packages\sklearn\cluster\_kmeans.py:1428: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\NATRAJ\miniconda3\envs\datascience\Lib\site-packages\sklearn\cluster\_kmeans.py:1428: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\NATRAJ\miniconda3\envs\datascience\Lib\site-packages\sklearn\cluster\_kmeans.py:1428: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\NATRAJ\miniconda3\envs\datascience\Lib\site-packages\sklearn\cluster\_kmeans.py:1428: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
