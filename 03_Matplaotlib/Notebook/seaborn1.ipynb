# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.DataFrame({
    "Hours": [1, 2, 3, 4, 5, 6, 7, 8],
    "Marks": [45, 50, 55, 62, 68, 75, 82, 90]
})
df
# Out:
#    Hours  Marks
# 0      1     45
# 1      2     50
# 2      3     55
# 3      4     62
# 4      5     68
# 5      6     75
# 6      7     82
# 7      8     90

# %%
plt.scatter(df["Hours"],df["Marks"])

# %%
sns.scatterplot(data=df, x="Hours", y="Marks")
# Out:
# <Axes: xlabel='Hours', ylabel='Marks'>

# %%
marks = [45, 50, 52, 55, 58, 60, 62, 64, 65, 67, 70, 95]
sns.boxplot(x = marks)
# Out:
# <Axes: >

# %%
import seaborn as sns
import matplotlib.pyplot as plt

marks = [45, 50, 52, 55, 58, 60, 62, 64, 65, 67, 70, 95]

sns.boxplot(x=marks)

plt.title("Marks Distribution")
# Out:
# Text(0.5, 1.0, 'Marks Distribution')

# %%
df = pd.DataFrame({
    "Study": [2, 4, 6, 8, 10],
    "Sleep": [8, 7, 7, 6, 5],
    "Marks": [50, 60, 70, 80, 90]
})
df
# Out:
#    Study  Sleep  Marks
# 0      2      8     50
# 1      4      7     60
# 2      6      7     70
# 3      8      6     80
# 4     10      5     90

# %%
df.corr()
# Out:
#           Study     Sleep     Marks
# Study  1.000000 -0.970725  1.000000
# Sleep -0.970725  1.000000 -0.970725
# Marks  1.000000 -0.970725  1.000000

# %%
sns.heatmap(df.corr(), annot = True)
# Out:
# <Axes: >

# %%
sns.boxplot(x=marks)
plt.title("Marks")
plt.grid()

# %%
sns.heatmap(df.corr(), annot=True)
plt.title("Correlation Heatmap")
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %%
gender = ["Male", "Female", "Male", "Male", "Female", "Female", "Male"]

# %%
sns.countplot(x=gender)
# Out:
# <Axes: ylabel='count'>
