# %%
import pandas as pd

# %%
marks = pd.Series([85,92,76,88,95])
marks
# Out:
# 0    85
# 1    92
# 2    76
# 3    88
# 4    95
# dtype: int64

# %%
marks.mean()
# Out:
# np.float64(87.2)

# %%
marks.max()
# Out:
# np.int64(95)

# %%
marks.min()
# Out:
# np.int64(76)

# %%
marks.sum()
# Out:
# np.int64(436)

# %%
greater = marks[marks>80]
greater
# Out:
# 0    85
# 1    92
# 3    88
# 4    95
# dtype: int64
