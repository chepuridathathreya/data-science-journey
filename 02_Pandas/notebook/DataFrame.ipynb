# %%
import pandas as pd

# %%
students = {
    "Name": ["sai","hari","ravi","ram"],
    "Age": [20,18,20,23],
    "Marks": [85,85,48,79]
}
df = pd.DataFrame(students)
df
# Out:
#    Name  Age  Marks
# 0   sai   20     85
# 1  hari   18     85
# 2  ravi   20     48
# 3   ram   23     79

# %%
df.shape
# Out:
# (4, 3)

# %%
df.size
# Out:
# 12

# %%
df.ndim
# Out:
# 2

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Marks'], dtype='str')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
df["Age"]
# Out:
# 0    20
# 1    18
# 2    20
# 3    23
# Name: Age, dtype: int64

# %%
type(df["Age"])
# Out:
# pandas.Series

# %%
type(df[["Age"]])
# Out:
# pandas.DataFrame

# %%
df[["Age"]]
# Out:
#    Age
# 0   20
# 1   18
# 2   20
# 3   23

# %%
df["Age"]
# Out:
# 0    20
# 1    18
# 2    20
# 3    23
# Name: Age, dtype: int64

# %%
df[["Name","Marks"]]
# Out:
#    Name  Marks
# 0   sai     85
# 1  hari     85
# 2  ravi     48
# 3   ram     79
