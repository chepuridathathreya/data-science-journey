# %%
import pandas as pd
#WORKING WITH SERIES IN PANDAS

# %%
age = pd.Series([20,21,22,23])
age
# Out:
# 0    20
# 1    21
# 2    22
# 3    23
# dtype: int64

# %%
age.shape
# Out:
# (4,)

# %%
age.size
# Out:
# 4

# %%
age.ndim
# Out:
# 1

# %%
age.dtype
# Out:
# dtype('int64')

# %%
age[0]
# Out:
# np.int64(20)

# %%
age[1:3]
# Out:
# 1    21
# 2    22
# dtype: int64

# %%
age[1:3]
# Out:
# 1    21
# 2    22
# dtype: int64

# %%
age
# Out:
# 0    20
# 1    21
# 2    22
# 3    23
# dtype: int64

# %%
type(age)
# Out:
# pandas.Series

# %%
type(age[0])
# Out:
# numpy.int64

# %%
age.mean()
# Out:
# np.float64(21.5)

# %%
age.max()
# Out:
# np.int64(23)

# %%
age.min()
# Out:
# np.int64(20)

# %%
age.sum()
# Out:
# np.int64(86)

# %%
age+5
# Out:
# 0    25
# 1    26
# 2    27
# 3    28
# dtype: int64

# %%
age
# Out:
# 0    20
# 1    21
# 2    22
# 3    23
# dtype: int64

# %%
a = pd.Series([21,23,24,25],index = ["Ram", "Sai", "Robo","Siva"])
a
# Out:
# Ram     21
# Sai     23
# Robo    24
# Siva    25
# dtype: int64

# %%
a["Sai"]
# Out:
# np.int64(23)

# %%
a.index
# Out:
# Index(['Ram', 'Sai', 'Robo', 'Siva'], dtype='str')

# %%
a.values
# Out:
# array([21, 23, 24, 25])

# %%
a
# Out:
# Ram     21
# Sai     23
# Robo    24
# Siva    25
# dtype: int64

# %%
a["Sai"]=203
a
# Out:
# Ram      21
# Sai     203
# Robo     24
# Siva     25
# dtype: int64

# %%
a["Sai"]-192
a
# Out:
# Ram     21
# Sai     11
# Robo    24
# Siva    25
# dtype: int64

# %%
#USING DICTIONARY 
student = {
    "Sai":85,
    "Fairy":99,
    "srikant":39
}
marks = pd.Series(student)
marks
# Out:
# Sai        85
# Fairy      99
# srikant    39
# dtype: int64

# %%
student
# Out:
# {'Sai': 85, 'Fairy': 99, 'srikant': 39}
