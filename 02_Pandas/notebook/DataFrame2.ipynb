# %%
import pandas as pd

# %%
students = {
    "Name": ["Ram", "Shyam", "Hari", "Ravi"],
    "Age": [20, 21, 19, 22],
    "Marks": [85, 92, 76, 88]
}
df = pd.DataFrame(students)
df
# Out:
#     Name  Age  Marks
# 0    Ram   20     85
# 1  Shyam   21     92
# 2   Hari   19     76
# 3   Ravi   22     88

# %%
df.loc[2]
# Out:
# Name     Hari
# Age        19
# Marks      76
# Name: 2, dtype: object

# %%
df.iloc[2]
# Out:
# Name     Hari
# Age        19
# Marks      76
# Name: 2, dtype: object

# %%
df.loc[2,"Marks"]
# Out:
# np.int64(76)

# %%
df.iloc[2,1]
# Out:
# np.int64(19)

# %%
df
# Out:
#     Name  Age  Marks
# 0    Ram   20     85
# 1  Shyam   21     92
# 2   Hari   19     76
# 3   Ravi   22     88

# %%
df.loc[3]
# Out:
# Name     Ravi
# Age        22
# Marks      88
# Name: 3, dtype: object

# %%
df.loc[3,"Age"]
# Out:
# np.int64(22)

# %%
df.iloc[3,1]
# Out:
# np.int64(22)

# %%
df["Marks"]
# Out:
# 0    85
# 1    92
# 2    76
# 3    88
# Name: Marks, dtype: int64

# %%
df.loc[1:3]
# Out:
#     Name  Age  Marks
# 1  Shyam   21     92
# 2   Hari   19     76
# 3   Ravi   22     88

# %%
df.iloc[1:3]
# Out:
#     Name  Age  Marks
# 1  Shyam   21     92
# 2   Hari   19     76

# %%
df
# Out:
#     Name  Age  Marks
# 0    Ram   20     85
# 1  Shyam   21     92
# 2   Hari   19     76
# 3   Ravi   22     88

# %%
df.iloc[0:2,0:4:2]
# Out:
#     Name  Marks
# 0    Ram     85
# 1  Shyam     92

# %%
df.loc[0:1, "Name":"Marks"]
# Out:
#     Name  Age  Marks
# 0    Ram   20     85
# 1  Shyam   21     92

# %%
df.iloc[0:2, 0:2]
# Out:
#     Name  Age
# 0    Ram   20
# 1  Shyam   21

# %%
df.loc[0:1, "Name":"Age"]
# Out:
#     Name  Age
# 0    Ram   20
# 1  Shyam   21

# %%
df
# Out:
#     Name  Age  Marks
# 0    Ram   20     85
# 1  Shyam   21     92
# 2   Hari   19     76
# 3   Ravi   22     88

# %%
df.loc[0:1, ["Name", "Marks"]]
# Out:
#     Name  Marks
# 0    Ram     85
# 1  Shyam     92

# %%
df.loc[:, ["Age"]]
# Out:
#    Age
# 0   20
# 1   21
# 2   19
# 3   22

# %%
df
# Out:
#     Name  Age  Marks
# 0    Ram   20     85
# 1  Shyam   21     92
# 2   Hari   19     76
# 3   Ravi   22     88

# %%
df.iloc[0:2,0:4:2]
# Out:
#     Name  Marks
# 0    Ram     85
# 1  Shyam     92
