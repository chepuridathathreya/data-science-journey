# %%
import numpy as np
data1 = [10,11,12,13,1000]
print("Mean = ", np.mean(data))
print("Median = ", np.median(data))
# Out:
# Mean =  209.2
# Median =  12.0

# %%
data = [10, 20, 30, 40, 50, 60, 70, 80]
print(np.percentile(data, 25))
print(np.percentile(data, 50))
print(np.percentile(data, 75))
# Out:
# 27.5
# 45.0
# 62.5
