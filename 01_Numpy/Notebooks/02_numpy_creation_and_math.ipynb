# %%
import numpy as np

# %%
a = np.zeros(5)
a
a.dtype
# Out:
# dtype('float64')

# %%
b = np.ones(5)
b
# Out:
# array([1., 1., 1., 1., 1.])

# %%
b.dtype
# Out:
# dtype('float64')

# %%
c = np.full(5,7)
c
# Out:
# array([7, 7, 7, 7, 7])

# %%
ar = np.arange(2,20,3)
ar
# Out:
# array([ 2,  5,  8, 11, 14, 17])

# %%
np.linspace(0,10,5)
# Out:
# array([ 0. ,  2.5,  5. ,  7.5, 10. ])

# %%
np.arange(0,10,2)
# Out:
# array([0, 2, 4, 6, 8])

# %%
np.arange(20,2)
# Out:
# array([], dtype=int64)
