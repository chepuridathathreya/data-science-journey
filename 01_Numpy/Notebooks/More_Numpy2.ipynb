# %%
import numpy as np
#AGGREGATE FUNTIONS IN 1D ARRAY

# %%
a = np.array([10,20,30,40,50])

# %%
a.sum()
# Out:
# np.int64(150)

# %%
a.mean()
# Out:
# np.float64(30.0)

# %%
a.min()
# Out:
# np.int64(10)

# %%
a.max()
# Out:
# np.int64(50)

# %%
a.argmax() #WHERE THE LARGE NUMBER IS
# Out:
# np.int64(4)

# %%
a.argmin() #WHERE THE SMALLLEST NUMBER IS
# Out:
# np.int64(0)

# %%
a.std()
# Out:
# np.float64(14.142135623730951)

# %%
a.var()
# Out:
# np.float64(200.0)

# %%
#AGGREGATE FUNTIONS IN 2D ARRAY
b = np.array([
    [10,20,30],
    [40,50,60],
    [70,80,90],
])
b
# Out:
# array([[10, 20, 30],
#        [40, 50, 60],
#        [70, 80, 90]])

# %%
b.sum()
# Out:
# np.int64(450)

# %%
b.sum(axis=0)
# Out:
# array([120, 150, 180])

# %%
b.sum(axis=1)
# Out:
# array([ 60, 150, 240])

# %%
b.max(axis=1)
# Out:
# array([30, 60, 90])

# %%
#BOOLEAN INDEXING
m = np.array([23,56,78,34,56,76,73])
m
# Out:
# array([23, 56, 78, 34, 56, 76, 73])

# %%
print(m>35)
# Out:
# [False  True  True False  True  True  True]

# %%
m == 35
# Out:
# array([False, False, False, False, False, False, False])

# %%
m !=73
# Out:
# array([ True,  True,  True,  True,  True,  True, False])

# %%
m[m>35]
# Out:
# array([56, 78, 56, 76, 73])

# %%
m[(m > 50) & (m < 90)]
# Out:
# array([56, 78, 56, 76, 73])

# %%
marks = np.array([45,67,89,23,91])

# %%
marks[marks>80]
# Out:
# array([89, 91])

# %%
#BRODCASTING IN NUMPY
a = np.array([10,20,30,40])
a + 10
# Out:
# array([20, 30, 40, 50])

# %%
a
# Out:
# array([10, 20, 30, 40])

# %%
b = np.array([40,30,20,10])
a+b
# Out:
# array([50, 50, 50, 50])

# %%
a*b
# Out:
# array([400, 600, 600, 400])

# %%
#NOW IN 2D ELEMENTS
a = np.array([
    [1,2,3],
    [4,5,6]
])
a+10
# Out:
# array([[11, 12, 13],
#        [14, 15, 16]])

# %%
a = np.array([
    [1,2,3],
    [4,5,6]
])

b = np.array([10,20,30])

a+b
# Out:
# array([[11, 22, 33],
#        [14, 25, 36]])

# %%
a = np.array([
    [1],
    [2]
])

b = np.array([10,20,30])

a+b
# Out:
# array([[11, 21, 31],
#        [12, 22, 32]])

# %%
#MORE OF NUMPY
arr = np.array([1,2,2,3,4,4,5,5,5])

np.unique(arr)
# Out:
# array([1, 2, 3, 4, 5])

# %%
arr = np.array([8,3,1,6,2])

np.sort(arr)
# Out:
# array([1, 2, 3, 6, 8])

# %%
arr
# Out:
# array([8, 3, 1, 6, 2])

# %%
arr = np.array([1,2,3,4,5,6])

np.count_nonzero(arr)
# Out:
# np.int64(6)

# %%
arr = np.array([1,0,0,4,0,6])

np.count_nonzero(arr)
# Out:
# np.int64(3)

# %%
arr = np.array([10,20,30,40,50])

np.where(arr>25) #RETURNS INDEXES
# Out:
# (array([2, 3, 4]),)

# %%
arr[np.where(arr>25)] #RETURNS THE ACTUAL VALES
# Out:
# array([30, 40, 50])

# %%
arr = np.array([True,True,False])

np.any(arr)
# Out:
# np.True_

# %%
np.all(arr)
# Out:
# np.False_

# %%
arr = np.array([10,25,80,120])

np.clip(arr,20,100)
# Out:
# array([ 20,  25,  80, 100])
