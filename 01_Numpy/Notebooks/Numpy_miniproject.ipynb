# %%
import numpy as np

# %%
marks = np.array([
    [85,78,92],
    [67,88,75],
    [95,91,89],
    [72,64,81]
])

# %%
marks.shape # 4 students and 3 subjects
# Out:
# (4, 3)

# %%
marks.size
# Out:
# 12

# %%
highest_score = marks.max(axis=0)
highest_score #In maths and physics std2 got highest_score and in chemistry std1 got highest_score
# Out:
# array([95, 91, 92])

# %%
low_score= marks.min(axis=0)
low_score
# Out:
# array([67, 64, 75])

# %%
avg_score = marks.mean(axis=0) #avg score in maths physics and chemistry
avg_score
# Out:
# array([79.75, 80.25, 84.25])

# %%
avgof_std = marks.mean(axis=1)
avgof_std
# Out:
# array([85.        , 76.66666667, 91.66666667, 72.33333333])

# %%
distintion = marks[marks>90]
distintion
# Out:
# array([92, 95, 91])

# %%
marks
# Out:
# array([[85, 78, 92],
#        [67, 88, 75],
#        [95, 91, 89],
#        [72, 64, 81]])

# %%
marks+5
# Out:
# array([[ 90,  83,  97],
#        [ 72,  93,  80],
#        [100,  96,  94],
#        [ 77,  69,  86]])

# %%
marks.flatten()
# Out:
# array([85, 78, 92, 67, 88, 75, 95, 91, 89, 72, 64, 81])

# %%
marks.reshape(2,6)
# Out:
# array([[85, 78, 92, 67, 88, 75],
#        [95, 91, 89, 72, 64, 81]])
